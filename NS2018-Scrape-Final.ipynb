# %% [markdown]
# # GeoPlot of DH2018 Presenters
#
# ## GOAL:
# - Create a table of presenters suitable for mapping
# - with columns for: 1) Presenter, 2) Institution, 3) Presentation Title
#
# ### Note1:
# - Some presenters' institutions are identified by footnote number; footnotes are not in order, so you need to use regex to split the presenter/footnote number into groups and match with the corresponding institution/footnote
#
# ### Note2:
# - The presenter is used as the index (unit of measurement). BUT some presenters gave more than one paper... So, you could do an additional layer of analysis and aggregate the presentation titles from the same author/institution into one cell. OR you could plot the presentation titles instead of the people. OR the institution.... etc. etc.
# - One way to tinker with different arrangements (without creating endless new files) is with pandas dataframes (See Example: NS2018-DF notebook)

# %%
#Import Libraries
from bs4 import BeautifulSoup
import requests
import re
import csv

#Create Soup
r  = requests.get("https://www.conftool.pro/dh2018/index.php?page=browseSessions&print=head&doprint=yes&presentations=show")
soup = BeautifulSoup(r.content, "lxml")
#print(soup.prettify())

#create file, write header
with open('NSFinal.csv', 'a') as csvfile:
    fieldnames = ['Name', 'Institution', 'Title']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()

#For each unit in the schedule
for slot in soup.find_all("td", {"class": "whitebg topline_printonly leftline_printonly left"}):
    #print(titles)
    
    #Check if empty
    if slot.find("p", {"class": "paper_title"}):
        
        #Get Author
        authors = slot.find("p", {"class": "paper_author"})
        #authors2 = authors.get_text()
        #print(authors2)
        
        #Get Title
        title = slot.find("p", {"class": "paper_title"})
        title2 = title.get_text()
        
        #If author institution identified via footnote... do this:
        if authors.find("sup"):
            authors2 = authors.get_text()
            #print(authors2)
            a_list = authors2.split(', ')
            #print(a_list)
            for a in a_list:
                #print(a)
                n = re.search('([a-zA-Z]\D*)(\d)', a)
                name = n.group(1)
                num = n.group(2)
                #print(name)
                #print(num)
                
                #Get Institutions
                unis = slot.find("p", {"class": "paper_organisation"})
                unis2 = unis.get_text()
                #print(unis2)
                unis3 = unis2.split(';')
                #print(unis3)
                
                for u in unis3:
                    u = re.search('.*(\d):\s([A-Z].*)', u)
                    u_num = u.group(1)
                    u_name = u.group(2)
                    #print(u_num)
                    #print(u_name)
                    
                    #If the Institution footnote number matches the Name footnote... do this:
                    if u_num == num:
                        #print("Match!")
                        #print(name)
                        #print(u_name)
                        #print(title2)
                        
                        #Write to .csv file
                        with open('NSFinal.csv', 'a') as csvfile:
                            fieldnames = ['Name', 'Institution', 'Title']
                            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
                            #writer.writeheader()
                            writer.writerow({
                            "Name" : name,
                            "Institution" : u_name,
                            "Title" : title2})
                            csvfile.close()
            
        else:
            authors2 = authors.get_text()
            #print(authors2)
            a_list = authors2.split(', ')
            #print(a_list)
            for a in a_list:
            
                #Get Institutions
                unis = slot.find("p", {"class": "paper_organisation"})
                u1 = unis.get_text()
                u2 = re.search('([A-Z].*)', u1)
                u_name = u2.group(1)
                #print(u_name)

                #Get Name
                a2 = re.search('([A-Z].*)', a)
                name = a2.group(1)
                
                """
                final = {
                "Name" : name,
                "Institution" : u_name,
                "Title" : title2,
                }
                print(final)
                """

                #Write to .csv file
                with open('NSFinal.csv', 'a') as csvfile:
                    fieldnames = ['Name', 'Institution', 'Title']
                    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
                    #writer.writeheader()
                    writer.writerow({
                    "Name" : name,
                    "Institution" : u_name,
                    "Title" : title2})
                    csvfile.close()

# %% [markdown]
# # Create a Dataframe (Index by Title, Name or Institution)

# %%
import pandas as pd
df = pd.read_csv("NSFinal.csv")
df.head()
# Out:
#                     Name                                        Institution  \
# 0           Leif Isaksen               University of Exeter, United Kingdom
# 1  Gimena del Río Riande  Consejo Nacional de Investigaciones Científica...
# 2         Romina De León  Consejo Nacional de Investigaciones Científica...
# 3        Nidia Hernández  Consejo Nacional de Investigaciones Científica...
# 4   Elisa Beshero-Bondar  University of Pittsburgh at Greensburg, United...
#
#                                                Title
# 0  Getting to Grips with Semantic and Geo-annotat...
# 1  Getting to Grips with Semantic and Geo-annotat...
# 2  Getting to Grips with Semantic and Geo-annotat...
# 3  Getting to Grips with Semantic and Geo-annotat...
# 4  An introduction to encoding and processing tex...

# %%
#Number of Unique Presentations
print(len(df.Title.unique()))

#Number of Presenters
print(len(df.Name.unique()))

#Number of Institutions
print(len(df.Institution.unique()))
# Out:
# 97
# 358
# 213

# %%
#Create a new dataframe merging rows with the same title
df_a = df.groupby(['Title'])['Name'].apply(lambda x: '; '.join(x.astype(str))).reset_index()
df_b = df.groupby(['Title'])['Institution'].apply(lambda x: '; '.join(x.astype(str))).reset_index()
df_new = pd.merge(df_a, df_b, on='Title')
df_new
# Out:
#                                                 Title  \
# 0   4 Ríos: una construcción transmedia de memoria...
# 1   A Corpus Approach to Manuscript Abbreviations ...
# 2   Abundance and Access: Early Modern Political L...
# 3   Alfabetización Digital, Prácticas y Posibilida...
# 4   An introduction to encoding and processing tex...
# 5   Archiving Small Twitter Datasets for Text Anal...
# 6   Archivos Abiertos y Públicos para el Postconfl...
# 7   Authorship Attribution Variables and Victorian...
# 8   Balanceándonos entre la aserción de la identid...
# 9   Beyond Image Search: Computer Vision in Wester...
# 10  Bridging Between The Spaces: Cultural Represen...
# 11  Bridging Cultures Through Mapping Practices: S...
# 12  Bridging Justice Based Practices for Archives ...
# 13  Building Bridges With Interactive Visual Techn...
# 14  Building International Bridges Through Digital...
# 15  Can Non-Representational Space Be Mapped? The ...
# 16  Challenges in Enabling Mixed Media Scholarly R...
# 17                               Chinese Text Project
# 18  Classical Chinese Sentence Segmentation for To...
# 19  Computational Analysis and Visual Stylometry o...
# 20                              Computer Vision in DH
# 21  Creating and Implementing an Ontology of Docum...
# 22  Critical Data Literacy in the Humanities Class...
# 23  Critical Theory + Empirical Practice: “The Arc...
# 24  DH in 3D: Multidimensional Research and Educat...
# 25  Dall’Informatica umanistica alle Digital Human...
# 26  Designing Digital Collections for Social Relev...
# 27  Designing writing: Educational technology as a...
# 28  Digital Chicago: #DH As A Bridge To A City’s Past
# 29  Digital Decolonizations: Remediating the Popol...
# ..                                                ...
# 67                               New Scholars Seminar
# 68  Novas Faces Da Arte Política: Ações Coletivas ...
# 69  Organising the Unknown: A Concept for the Sign...
# 72  Trinity College, United States of America; Wak...
# 73  Pontificia Universidad Católica del Perú, Peru...
# 74  Princeton University, United States of America...
# 75  Bucknell University, United States of America;...
# 76  University of Texas at Austin, United States o...
# 77  University of Toronto, Canada; University of T...
# 78  Bucknell University, United States of America;...
# 79  Harvard University, United States of America; ...
# 80                    El Colegio de Michoacán, Mexico
# 81  Leipzig University, Germany; New York Universi...
# 82  Biblioteca Nacional de colombia, Colombia; Bib...
# 83  University of Houston, United States of Americ...
# 84  Center for Advanced Study in the Visual Arts, ...
# 85  University of the Pacific, United States of Am...
# 86  CNRS, Huma-Num, France; CNRS, Huma-Num, France...
# 87  The Graduate Center of the City University of ...
# 88  University of Antwerp, Belgium; University of ...
# 89  National Research University Higher School of ...
# 90  Activista en lenguas indígenas / Indigenous La...
# 91  University of Illinois, United States of Ameri...
# 92  University of Notre Dame, United States of Ame...
# 93  Texas A&M University, United States of America...
# 94  UN/ECLAC, Chile; CONICET, Argentina; New York ...
# 95  Doctorado de Ecosur (Chiapas Mexico), Sursiend...
# 96     University of Maryland; University of Maryland
#
# [97 rows x 3 columns]

# %%
#Create a new dataframe merging rows with the same Institution
df_1 = df.groupby(['Institution'])['Name'].apply(lambda x: '; '.join(x.astype(str))).reset_index()
df_2 = df.groupby(['Institution'])['Title'].apply(lambda x: '; '.join(x.astype(str))).reset_index()
df_new2 = pd.merge(df_1, df_2, on='Institution')
df_new2
# Out:
#                                            Institution  \
# 0    Academy of Motion Picture Arts & Sciences, Uni...
# 1    Activista en lenguas indígenas / Indigenous La...
# 2                     Aix-Marseille University, IrAsia
# 3                            Ashesi University College
# 4                         Austrian Academy of Sciences
# 5                                          BNF, France
# 6                                         Bard College
# 7            Biblioteca Nacional de colombia, Colombia
# 8             Boston College, United States of America
# 9          Boston University, United States of America
# 10   Brigham Young University, United States of Ame...
# 11                                    Brown University
# 12          Brown University, United States of America
# 13       Bucknell University, United States of America
# 14                                     CNR-ISTI, Italy
# 15                              CNRS, Huma-Num, France
# 16   CONICET (Consejo Nacional de Investigaciones C...
# 17                                  CONICET, Argentina
# 18   California State University Fullerton, United ...
# 19   California State University, Sacramento, Calif...
# 20   Center for Advanced Study in the Visual Arts, ...
# 21   Center for Interdisciplinary Digital Research,...
# 22          City, University of London, United Kingdom
# 23                                 Columbia University
# 24                       Columbia University Libraries
# 25       Columbia University, United States of America
# 26                       Complutense University, Spain
# 27   Consejo Nacional de Investigaciones Científica...
# 28                    Create Caribbean, Inc., Dominica
# 29                                 Cubaliteraria, Cuba
# ..                                                 ...
# 183                                University of Texas
# 184  University of Texas at Austin, United States o...
# 185                        University of Texas, Austin
# 186                       University of Texas, El Paso
# 187                      University of Toronto, Canada
# 188  University of Twente, Netherlands Institute fo...
# 189                    University of Tübingen, Germany
# 190                     University of Victoria, Canada
# 191   University of Virginia, United States of America
# 192                              University of Warwick
# 193                           University of Washington
# 194  University of Washington, United States of Ame...
# 195            University of Western Sydney, Australia
# 196                    University of Wisconsin-Madison
# 212                     Angel David Nieves; Gabor Toth
#
#                                                  Title
# 0    Indexing Multilingual Content with the Oral Hi...
# 1                                  Tramando la palabra
# 2    Bridging Cultures Through Mapping Practices: S...
# 3    Global Perspectives On Decolonizing Digital Pe...
# 4    Innovations in Digital Humanities Pedagogy: Lo...
# 5    The Impact of FAIR Principles on Scientific Co...
# 6                              Experimental Humanities
# 7    Si Las Humanidades Digitales Fueran Un Círculo...
# 8           Precarious Labor in the Digital Humanities
# 9          Justice-Based DH, Practice, and Communities
# 10   Innovations in Digital Humanities Pedagogy: Lo...
# 11   An introduction to encoding and processing tex...
# 12   Precarious Labor in the Digital Humanities; Di...
# 13   Innovations in Digital Humanities Pedagogy: Lo...
# 14   Building Bridges With Interactive Visual Techn...
# 15   The Impact of FAIR Principles on Scientific Co...
# 16   Alfabetización Digital, Prácticas y Posibilida...
# 17                            Where is the Open in DH?
# 18   Global Perspectives On Decolonizing Digital Pe...
# 19   La Aptitud para Encontrar Patrones y la Produc...
# 20   The (Digital) Space Between: Notes on Art Hist...
# 21   Histonets, Turning Historical Maps into Digita...
# 22   Archiving Small Twitter Datasets for Text Anal...
# 23                             Experimental Humanities
# 24   Digital Humanities in Middle and High School: ...
# 25   Does "Late Style" Exist? New Stylometric Appro...
# 26   Herramientas Para Los Usuarios: Colecciones y ...
# 27   Getting to Grips with Semantic and Geo-annotat...
# 28   Digital Humanities in Middle and High School: ...
# 29   Humanidades Digitales en Cuba: Avances y Persp...
# ..                                                 ...
# 183  Bridging Cultures Through Mapping Practices: S...
# 184  Digital Humanities and Colonial Latin American...
# 185  Can Non-Representational Space Be Mapped? The ...
# 186  Bridging Between The Spaces: Cultural Represen...
# 187  Remediating Machistán: Bridging Espacios Queer...
# 188  Challenges in Enabling Mixed Media Scholarly R...
# 189  Perspectivas Digitales y a Gran Escala en el E...
# 190  Innovations in Digital Humanities Pedagogy: Lo...
# 191  Measured Unrest In The Poetry Of The Black Art...
# 192  Experimental Humanities; Can Non-Representatio...
# 193  Bridging Cultures Through Mapping Practices: S...
# 194  Unanticipated Afterlives: Resurrecting Dead Pr...
# 195  DH in 3D: Multidimensional Research and Educat...
# 196  Labeculæ Vivæ. Building a Reference Library of...
# 197  Critical Theory + Empirical Practice: “The Arc...
# 198  The Digitization of “Oriental” Manuscripts: Re...
# 199  From print to digital: A web-edition of Giacom...
# 200  From print to digital: A web-edition of Giacom...
# 201  Dall’Informatica umanistica alle Digital Human...
# 202  Innovations in Digital Humanities Pedagogy: Lo...
# 203  Estudio exploratorio sobre los territorios de ...
# 204  The Impact of FAIR Principles on Scientific Co...
# 205  The Impact of FAIR Principles on Scientific Co...
# 206  The Impact of FAIR Principles on Scientific Co...
# 207  Challenges in Enabling Mixed Media Scholarly R...
# 208  Challenges in Enabling Mixed Media Scholarly R...
# 209         Precarious Labor in the Digital Humanities
# 210                               New Scholars Seminar
# 211                     Reimagining the Humanities Lab
# 212  DH in 3D: Multidimensional Research and Educat...
#
# [213 rows x 3 columns]
